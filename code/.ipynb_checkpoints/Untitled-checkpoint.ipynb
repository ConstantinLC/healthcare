# %%
import pandas as pd
import numpy as np
import matplotlib
#matplotlib.use('pdf')
#from matplotlib import pyplot as plt
from keras import optimizers, losses, activations, models
from keras.callbacks import ModelCheckpoint, EarlyStopping, LearningRateScheduler, ReduceLROnPlateau
from keras.layers import Dense, Input, Dropout, Convolution1D, MaxPool1D, GlobalMaxPool1D, GlobalAveragePooling1D, \
    concatenate
from sklearn.metrics import accuracy_score, f1_score
from sklearn.model_selection import train_test_split

df_1 = pd.read_csv("../input/ptbdb_normal.csv", header=None)
df_2 = pd.read_csv("../input/ptbdb_abnormal.csv", header=None)
df = pd.concat([df_1, df_2])

df_train, df_test = train_test_split(df, test_size=0.2, random_state=1337, stratify=df[187])


Y = np.array(df_train[187].values).astype(np.int8)
X = np.array(df_train[list(range(187))].values)[..., np.newaxis]

Y_test = np.array(df_test[187].values).astype(np.int8)
X_test = np.array(df_test[list(range(187))].values)[..., np.newaxis]


def get_model():
    nclass = 1
    inp = Input(shape=(187, 1))
    current_layer = keras.Conv1D(filters=32, kernel_size=5, strides=1)(inp)

    for i in range(5):
        current_layer = conv_unit(i + 1, current_layer)

    current_layer = keras.Flatten()(current_layer)
    current_layer = keras.Dense(32, name='FC1', activation='relu')(current_layer)
    logits = keras.Dense(5, name='Output')(current_layer)
    dense_1 = Dense(nclass, activation=activations.sigmoid, name="Output")(dense_1)

    model = models.Model(inputs=inp, outputs=dense_1)
    opt = optimizers.Adam(0.001)

    model.compile(optimizer=opt, loss=losses.binary_crossentropy, metrics=['acc'])
    model.summary()
    return model

model = get_model()
file_path = "baseline_cnn_ptbdb.h5"
checkpoint = ModelCheckpoint(file_path, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
early = EarlyStopping(monitor="val_acc", mode="max", patience=5, verbose=1)
redonplat = ReduceLROnPlateau(monitor="val_acc", mode="max", patience=3, verbose=2)
callbacks_list = [checkpoint, early, redonplat]  # early

history = model.fit(X, Y, epochs=1000, verbose=2, callbacks=callbacks_list, validation_split=0.1)
model.load_weights(file_path)

'''plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.savefig('model_accuracy_baseline.png')
plt.clf()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.savefig('model_loss_baseline.png')'''

pred_test = model.predict(X_test)
pred_test = (pred_test>0.5).astype(np.int8)

f1 = f1_score(Y_test, pred_test)

print("Test f1 score : %s "% f1)

acc = accuracy_score(Y_test, pred_test)

print("Test accuracy score : %s "% acc)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 187, 1)            0
# _________________________________________________________________
# conv1d_9 (Conv1D)            (None, 183, 16)           96
# _________________________________________________________________
# conv1d_10 (Conv1D)           (None, 179, 16)           1296
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 89, 16)            0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 89, 16)            0
# _________________________________________________________________
# conv1d_11 (Conv1D)           (None, 87, 32)            1568
# _________________________________________________________________
# conv1d_12 (Conv1D)           (None, 85, 32)            3104
# _________________________________________________________________
# max_pooling1d_5 (MaxPooling1 (None, 42, 32)            0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 42, 32)            0
# _________________________________________________________________
# conv1d_13 (Conv1D)           (None, 40, 32)            3104
# _________________________________________________________________
# conv1d_14 (Conv1D)           (None, 38, 32)            3104
# _________________________________________________________________
# max_pooling1d_6 (MaxPooling1 (None, 19, 32)            0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 19, 32)            0
# _________________________________________________________________
# conv1d_15 (Conv1D)           (None, 17, 256)           24832
# _________________________________________________________________
# conv1d_16 (Conv1D)           (None, 15, 256)           196864
# _________________________________________________________________
# global_max_pooling1d_2 (Glob (None, 256)               0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                16448
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_3_ptbdb (Dense)        (None, 1)                 65
# =================================================================
# Total params: 254,641
# Trainable params: 254,641
# Non-trainable params: 0
# _________________________________________________________________
# Train on 10476 samples, validate on 1165 samples
# Epoch 1/1000
#  - 4s - loss: 0.5196 - acc: 0.7289 - val_loss: 0.4466 - val_acc: 0.8112
#
# Epoch 00001: val_acc improved from -inf to 0.81116, saving model to baseline_cnn_ptbdb.h5
# Epoch 2/1000
#  - 3s - loss: 0.3738 - acc: 0.8354 - val_loss: 0.3899 - val_acc: 0.8197
#
# Epoch 00002: val_acc improved from 0.81116 to 0.81974, saving model to baseline_cnn_ptbdb.h5
# Epoch 3/1000
#  - 3s - loss: 0.2869 - acc: 0.8894 - val_loss: 0.2168 - val_acc: 0.9193
#
# Epoch 00003: val_acc improved from 0.81974 to 0.91931, saving model to baseline_cnn_ptbdb.h5
# Epoch 4/1000
#  - 3s - loss: 0.2413 - acc: 0.9056 - val_loss: 0.3304 - val_acc: 0.8412
#
# Epoch 00004: val_acc did not improve
# Epoch 5/1000
#  - 3s - loss: 0.2074 - acc: 0.9222 - val_loss: 0.1514 - val_acc: 0.9408
#
# Epoch 00005: val_acc improved from 0.91931 to 0.94077, saving model to baseline_cnn_ptbdb.h5
# Epoch 6/1000
#  - 3s - loss: 0.1778 - acc: 0.9336 - val_loss: 0.1626 - val_acc: 0.9313
#
# Epoch 00006: val_acc did not improve
# Epoch 7/1000
#  - 3s - loss: 0.1507 - acc: 0.9422 - val_loss: 0.1613 - val_acc: 0.9313
#
# Epoch 00007: val_acc did not improve
# Epoch 8/1000
#  - 3s - loss: 0.1418 - acc: 0.9464 - val_loss: 0.1359 - val_acc: 0.9433
#
# Epoch 00008: val_acc improved from 0.94077 to 0.94335, saving model to baseline_cnn_ptbdb.h5
# Epoch 9/1000
#  - 3s - loss: 0.1194 - acc: 0.9557 - val_loss: 0.1259 - val_acc: 0.9545
#
# Epoch 00009: val_acc improved from 0.94335 to 0.95451, saving model to baseline_cnn_ptbdb.h5
# Epoch 10/1000
#  - 3s - loss: 0.1104 - acc: 0.9587 - val_loss: 0.0960 - val_acc: 0.9665
#
# Epoch 00010: val_acc improved from 0.95451 to 0.96652, saving model to baseline_cnn_ptbdb.h5
# Epoch 11/1000
#  - 3s - loss: 0.1062 - acc: 0.9608 - val_loss: 0.0790 - val_acc: 0.9725
#
# Epoch 00011: val_acc improved from 0.96652 to 0.97253, saving model to baseline_cnn_ptbdb.h5
# Epoch 12/1000
#  - 3s - loss: 0.0978 - acc: 0.9642 - val_loss: 0.0896 - val_acc: 0.9708
#
# Epoch 00012: val_acc did not improve
# Epoch 13/1000
#  - 3s - loss: 0.0947 - acc: 0.9652 - val_loss: 0.0726 - val_acc: 0.9725
#
# Epoch 00013: val_acc did not improve
# Epoch 14/1000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-324c932cf742> in <module>()
#      62 callbacks_list = [checkpoint, early, redonplat]  # early
#      63
# ---> 64 history = model.fit(X, Y, epochs=1000, verbose=2, callbacks=callbacks_list, validation_split=0.1)
#      65 model.load_weights(file_path)
#      66
#
# /cluster/apps/python/3.6.4/lib64/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1703                               initial_epoch=initial_epoch,
#    1704                               steps_per_epoch=steps_per_epoch,
# -> 1705                               validation_steps=validation_steps)
#    1706
#    1707     def evaluate(self, x=None, y=None,
#
# /cluster/apps/python/3.6.4/lib64/python3.6/site-packages/keras/engine/training.py in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#    1233                         ins_batch[i] = ins_batch[i].toarray()
#    1234
# -> 1235                     outs = f(ins_batch)
#    1236                     if not isinstance(outs, list):
#    1237                         outs = [outs]
#
# /cluster/apps/python/3.6.4/lib64/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2476         session = get_session()
#    2477         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2478                               **self.session_kwargs)
#    2479         return updated[:len(self.outputs)]
#    2480
#
# /cluster/apps/python/3.6.4/lib64/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     903     try:
#     904       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 905                          run_metadata_ptr)
#     906       if run_metadata:
#     907         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /cluster/apps/python/3.6.4/lib64/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1138     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1139       results = self._do_run(handle, final_targets, final_fetches,
# -> 1140                              feed_dict_tensor, options, run_metadata)
#    1141     else:
#    1142       results = []
#
# /cluster/apps/python/3.6.4/lib64/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1319     if handle is None:
#    1320       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1321                            run_metadata)
#    1322     else:
#    1323       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /cluster/apps/python/3.6.4/lib64/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1325   def _do_call(self, fn, *args):
#    1326     try:
# -> 1327       return fn(*args)
#    1328     except errors.OpError as e:
#    1329       message = compat.as_text(e.message)
#
# /cluster/apps/python/3.6.4/lib64/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1310       self._extend_graph()
#    1311       return self._call_tf_sessionrun(
# -> 1312           options, feed_dict, fetch_list, target_list, run_metadata)
#    1313
#    1314     def _prun_fn(handle, feed_dict, fetch_list):
#
# /cluster/apps/python/3.6.4/lib64/python3.6/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1418         return tf_session.TF_Run(
#    1419             self._session, options, feed_dict, fetch_list, target_list,
# -> 1420             status, run_metadata)
#    1421
#    1422   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
